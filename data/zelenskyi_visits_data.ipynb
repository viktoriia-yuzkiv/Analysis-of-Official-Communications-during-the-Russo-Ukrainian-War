# %%
import pandas as pd

# %%
data_2021 = [
    ["United Arab Emirates", "Abu Dhabi", "14–15 February", "2021"],
    ["Qatar", "Doha", "5 April", "2021"],
    ["Turkey", "Istanbul", "10 April", "2021"],
    ["France", "Paris", "16 April", "2021"],
    ["Poland", "Warsaw", "3 May", "2021"],
    ["Lithuania", "Vilnius", "6–7 July", "2021"],
    ["Germany", "Berlin", "12 July", "2021"],
    ["Georgia", "Batumi", "19–20 July", "2021"],
    ["Moldova", "Chișinău", "27 August", "2021"],
    ["United States", "Washington, D.C. / San Francisco", "31 August", "2021"],
    ["United Kingdom", "Glasgow", "1–2 November", "2021"]
]


# Define the additional data for the year 2022.
data_2022 = [
    ["Germany", "Munich", "19 February", "2022"],
    ["United States", "Washington, D.C.", "21 December", "2022"],
    ["Poland", "Rzeszów", "22 December", "2022"]
]


# Data for the year 2023
data_2023 = [
    ["United Kingdom", "London, West Lulworth", "8 February", "2023"],
    ["France", "Paris", "8–9 February", "2023"],
    ["Belgium", "Brussels", "9 February", "2023"],
    ["Poland", "Rzeszów", "", "2023"],
    ["Poland", "Warsaw, Chełm", "5 April", "2023"],
    ["Finland", "Helsinki", "3 May", "2023"],
    ["Netherlands", "The Hague, Soesterberg", "3–4 May", "2023"],
    ["Italy", "Rome", "13 May", "2023"],
    ["Vatican City", "Vatican City", "", "2023"],
    ["Germany", "Berlin, Aachen", "14 May", "2023"],
    ["France", "Paris", "", "2023"],
    ["United Kingdom", "Ellesborough", "15 May", "2023"],
    ["Saudi Arabia", "Jeddah", "19 May", "2023"],
    ["Japan", "Hiroshima", "20 May", "2023"],
    ["Moldova", "Bulboaca", "1 June", "2023"],
    ["Bulgaria", "Sofia", "6 July", "2023"],
    ["Czech Republic", "Prague", "6–7 July", "2023"],
    ["Slovakia", "Bratislava", "7 July", "2023"],
    ["Turkey", "Istanbul", "7–8 July", "2023"],
    ["Lithuania", "Vilnius", "11–12 July", "2023"],
    ["Sweden", "Harpsund, Stenhammar Palace", "19–20 August", "2023"],
    ["Netherlands", "Eindhoven", "20 August", "2023"],
    ["Denmark", "Vojens, Copenhagen", "20–21 August", "2023"],
    ["Greece", "Athens", "21 August", "2023"],
    ["United States", "New York, Washington, D.C.", "18–22 September", "2023"],
    ["Canada", "Ottawa, Toronto", "22 September", "2023"],
    ["Spain", "Granada", "6 October", "2023"],
    ["Romania", "Bucharest", "10 October", "2023"],
    ["Belgium", "Brussels", "11 October", "2023"],
    ["Cape Verde", "Sal", "9 December", "2023"],
    ["Argentina", "Buenos Aires", "10 December", "2023"],
    ["United States", "Washington, D.C.", "11–12 December", "2023"],
    ["Norway", "Oslo", "13 December", "2023"],
    ["Germany", "Wiesbaden", "14 December", "2023"]
]

# Data for the year 2024
data_2024 = [
    ["Lithuania", "Vilnius", "10 January", "2024"],
    ["Estonia", "Tallinn", "11 January", "2024"],
    ["Latvia", "Riga", "", "2024"],
    ["Switzerland", "Davos", "16 January", "2024"]
]

# Combining all the data into one list
combined_data = data_2021 + data_2022 + data_2023 + data_2024

# Creating a DataFrame
df = pd.DataFrame(combined_data, columns=["country", "place", "day-month", "year"])
df
# Out:
#                  country                             place        day-month  \
# 0   United Arab Emirates                         Abu Dhabi   14–15 February
# 1                  Qatar                              Doha          5 April
# 2                 Turkey                          Istanbul         10 April
# 3                 France                             Paris         16 April
# 4                 Poland                            Warsaw            3 May
# 5              Lithuania                           Vilnius         6–7 July
# 6                Germany                            Berlin          12 July
# 7                Georgia                            Batumi       19–20 July
# 8                Moldova                          Chișinău        27 August
# 9          United States  Washington, D.C. / San Francisco        31 August
# 10        United Kingdom                           Glasgow     1–2 November
# ...
