# %% [markdown]
# ## In this notebook, we proceed to do the count vectorization, tf-idf and lda analysis of the topics present in both White House and European Commission
#
# ## Structure:
#     - Hello is it me you are looking for?
#     - Atomic by Blondie
#     - First we take Manhanttan.

# %% [markdown]
# ## Import functions

# %%
import pandas as pd
import numpy as np
import csv

import spacy
sp = spacy.load('en_core_web_sm')

from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

import os

from gensim.corpora.dictionary import Dictionary
from gensim import models
from sklearn.feature_extraction.text import CountVectorizer
from scipy.sparse import csr_matrix
from gensim.matutils import Sparse2Corpus


from sklearn.feature_extraction.text import CountVectorizer
from scipy.sparse import csr_matrix
from gensim.matutils import Sparse2Corpus
from gensim import corpora, models
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
path="/Users/ruimaciel/Desktop/Barcelona/NLP_I/NLP-Project/"
filename_EC ="data/theeuropeancommission_preprocessed.csv"
EC_data = pd.read_csv(os.path.join(path, filename_EC), sep=',', encoding='utf-8')
#Checking everything is fine
EC_data.head(5)
# Out:
#                                                Title        Date  \
# 0  European Commission authorises second safe and...  2021-01-06
# 1  Statement by President von der Leyen on the re...  2021-01-07
# 2  Commission proposes to purchase up to 300 mill...  2021-01-08
# 3  Speech by President von der Leyen at the One P...  2021-01-11
# 4  Coronavirus: Commission concludes exploratory ...  2021-01-12
#
#         Category                                               Text  \
# 0  Press Release  Today, the European Commission has granted a c...
# 1      Statement    What happened in Washington yesterday is as ...
# 2  Press Release  The European Commission today proposed to the ...
# 3         Speech  Merci Monsieur le Président.\nCher Emmanuel,\n...
# 4  Press Release  Today, the European Commission concluded explo...
#
#                                         text_preproc  \
# 0  today european commission grant conditional ma...
# 1  happen washington yesterday appalling outrageo...
# 2  european commission today propose EU member st...
# 3  merci monsieur le président cher emmanuel deli...
# 4  today european commission conclude exploratory...
#
#                                       titles_preproc  Ukraine
# 0  european commission authorise second safe effe...        0
# 1  statement president von der leyen recent devel...        0
# 2  commission propose purchase 300 million additi...        0
# 3   speech president von der leyen one planet summit        0
# 4  coronavirus commission conclude exploratory ta...        0

# %%
filename ="data/thewhitehouse_preprocessed_p1.csv"
WH_data_1 = pd.read_csv(os.path.join(path, filename), sep=',', encoding='utf-8')
filename ="data/thewhitehouse_preprocessed_p2.csv"
WH_data_2 = pd.read_csv(os.path.join(path, filename), sep=',', encoding='utf-8')
WH_data = pd.concat([WH_data_1, WH_data_2], ignore_index=True)
#Checking everything is fine
WH_data.head(5)
# Out:
#                                                Title        Date   Category  \
# 0  Fact Sheet: President-elect Biden Outlines COV...  2021-01-15  Statement
# 1      Fact Sheet: List of Agency Actions for Review  2021-01-20  Statement
# 2  Fact Sheet: President Biden Sends Immigration ...  2021-01-20  Statement
# 3  A Letter to Dr. Eric S. Lander, the President’...  2021-01-20  Statement
# 4                            Paris Climate Agreement  2021-01-20  Statement
#
#                                                 Text  \
# 0  Effectively and equitably vaccinating the U.S....
# 1  Actions Address the COVID-19 Pandemic, Provide...
# 2  The U.S. Citizenship Act of 2021 establishes a...
# 3  On January 15, 2021, then-President-Elect Bide...
# 4  ACCEPTANCE ON BEHALF OF THE UNITED STATES OF A...
#
#                                         text_preproc  \
# 0  effectively equitably vaccinate US population ...
# 1  actions address covid19 pandemic provide econo...
# 2  US citizenship act 2021 establish new system r...
# 3  january 15 2021 president elect biden send fol...
# 4  acceptance ON BEHALF UNITED STATES AMERICA jos...
#
#                                       titles_preproc  Ukraine
# 0  fact sheet president elect biden outlines covi...        0
# 1              fact sheet list agency actions review        0
# 2  fact sheet president biden sends immigration b...        0
# 3  letter dr eric lander president science adviso...        0
# 4                            paris climate agreement        0

# %% [markdown]
# ## CV, TD-IDF

# %%
def analyze_text_data(data, min_df, max_df):
    # Initialize CountVectorizer with specified parameters
    cv = CountVectorizer(ngram_range=(1,2), lowercase=True, min_df=min_df, max_df=max_df, stop_words='english')
    
    # Fit CountVectorizer and transform text and title data
    cv.fit(EC_data.text_preproc)
    vectorized_text = cv.transform(data.text_preproc).toarray()
    vectorized_title = cv.transform(data.titles_preproc).toarray()
    vectorized_text_title_weight = 2 * vectorized_title + vectorized_text
    
    # Apply SVD to CountVectorizer output
    svd = TruncatedSVD(n_components=10)
    U = svd.fit_transform(vectorized_text_title_weight)
    VT = svd.components_
    
    # Initialize TfidfVectorizer with specified parameters
    tfidf = TfidfVectorizer(ngram_range=(1,2), lowercase=True, min_df=min_df, max_df=max_df, stop_words='english')
    
    # Fit and transform text data using TfidfVectorizer
    tfidf_matrix_text = tfidf.fit_transform(EC_data.text_preproc)
    tfidf_matrix_title = tfidf.transform(EC_data.titles_preproc)
    
    # Perform SVD on TF-IDF matrices
    svd_tfidf = TruncatedSVD(n_components=10)
    U_text = svd_tfidf.fit_transform(tfidf_matrix_text)
    U_title = svd_tfidf.transform(tfidf_matrix_title)
    
    # Print top words for Count Vectorization
    print("Top words associated with each topic (Count Vectorization):")
    feature_names_count = cv.get_feature_names_out()
    for topic_idx, topic in enumerate(VT):
        top_words_idx = topic.argsort()[::-1][:10]  # Get indices of top 10 words
        top_words = [feature_names_count[i] for i in top_words_idx]
        print(f"Topic {topic_idx+1}: {', '.join(top_words)}")
    
    # Print top words for TF-IDF Vectorization
    print("\nTop words associated with each topic (TF-IDF Vectorization):")
    feature_names_tfidf = tfidf.get_feature_names_out()
    for topic_idx, topic in enumerate(svd_tfidf.components_):
        top_words_idx = topic.argsort()[::-1][:10]  # Get indices of top 10 words
        top_words = [feature_names_tfidf[i] for i in top_words_idx]
        print(f"Topic {topic_idx+1}: {', '.join(top_words)}")

analyze_text_data(EC_data, 0.02, 0.6)
# Out:
# Top words associated with each topic (Count Vectorization):
# Topic 1: energy, plan, investment, ukraine, global, include, resilience, recovery, billion, climate
# Topic 2: plan, resilience, recovery, recovery resilience, resilience plan, reform, investment, assessment, rrf, resilience facility
# Topic 3: ukraine, war, russia, people, ukrainian, recovery, russian, assistance, reform, financial
# Topic 4: include, cooperation, ukraine, international, security, global, continue, canada, development, health
# Topic 5: vaccine, health, global, world, covid19, pandemic, digital, africa, million, dose
# Topic 6: vaccine, energy, ukraine, million, africa, billion, health, covid19, team, team europe
# Topic 7: vaccine, gas, member states, price, market, supply, defence, energy, measure, covid19
# Topic 8: defence, investment, raw, critical, raw material, industry, material, strategic, critical raw, hydrogen
# Topic 9: payment, request, global, recovery resilience, preliminary assessment, preliminary, payment request, milestone, resilience, recovery
# Topic 10: climate, green, defence, hydrogen, emission, member states, ukraine, industry, innovation, deal
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: ukraine, energy, global, investment, plan, climate, want, vaccine, green, russia
# Topic 2: recovery resilience, plan, resilience, recovery, resilience plan, rrf, reform, resilience facility, payment, investment reform
# Topic 3: ukraine, russia, war, ukrainian, russian, putin, sanction, support ukraine, reconstruction, reform
# Topic 4: vaccine, dose, ukraine, health, covid19, variant, vaccination, million, million dose, covid19 vaccine
# Topic 5: ukraine, global, global gateway, gateway, partnership, leyen, der leyen, der, von der, von
# Topic 6: energy, gas, vaccine, price, russian, renewable, dose, supply, russia, hydrogen
# Topic 7: global gateway, gateway, investment, ukraine, africa, western, global, eur, western balkans, balkans
# Topic 8: western, balkans, western balkans, trade, agreement, china, economic, region, digital, cooperation
# Topic 9: western, western balkans, balkans, bauhaus, european bauhaus, new european, plan, assistance, conference, social
# Topic 10: western, payment, request, balkans, western balkans, payment request, energy, woman, preliminary assessment, preliminary

# %%
# Define the range of min_df and max_df values
min_df_values = [0.001, 0.01, 0.02, 0.1]
max_df_values = [0.3, 0.4, 0.5, 0.6]

# Iterate through each combination of min_df and max_df values
print("European Commission Top words associated with each topic Count Vectorization and TF-IDF Vectorization:")
for min_df in min_df_values:
    for max_df in max_df_values:
        # Print the current combination of min_df and max_df being analyzed
        print(f"\nAnalyzing with min_df = {min_df} and max_df = {max_df}:")
        
        # Call the analyze_text_data function for the current combination
        analyze_text_data(EC_data, min_df, max_df)
# Out:
# European Commission Top words associated with each topic Count Vectorization and TF-IDF Vectorization:
#
# Analyzing with min_df = 0.001 and max_df = 0.4:
# Top words associated with each topic (Count Vectorization):
# Topic 1: ukraine, resilience, recovery, digital, transition, recovery resilience, reform, security, russia, von
# Topic 2: resilience, recovery, recovery resilience, resilience plan, reform, assessment, digital, rrf, resilience facility, facility
# Topic 3: ukraine, war, russia, ukrainian, recovery, financial, assistance, russian, reform, recovery resilience
# Topic 4: vaccine, health, covid19, africa, dose, pandemic, team, team europe, production, covid19 vaccine
# Topic 5: security, health, canada, development, ukraine, vaccine, partnership, welcome, strengthen, commitment
# Topic 6: transition, ukraine, viet, viet nam, nam, emission, renewable, energy transition, hydrogen, africa
# Topic 7: defence, gas, supply, vaccine, price, industry, security, critical, industrial, russia
# Topic 8: raw, hydrogen, material, raw material, gateway, global gateway, critical, critical raw, ukraine, project
# Topic 9: payment, request, preliminary assessment, preliminary, payment request, milestone, positive preliminary, hydrogen, positive, assessment
# Topic 10: democracy, china, viet, viet nam, nam, defence, transition, vaccine, change, woman
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: ukraine, recovery, resilience, recovery resilience, vaccine, digital, reform, russia, transition, war
# Topic 2: recovery resilience, resilience, recovery, resilience plan, rrf, payment, resilience facility, reform, investment reform, request
# Topic 3: vaccine, dose, health, covid19, africa, variant, pandemic, vaccination, million dose, covid19 vaccine
# Topic 4: vaccine, ukraine, dose, covid19, ukrainian, variant, vaccination, health, million dose, russia
# Topic 5: ukraine, global gateway, gateway, partnership, development, der, leyen, der leyen, von der, assistance
# Topic 6: gas, hydrogen, price, renewable, russian, vaccine, clean, supply, russia, request
# Topic 7: bauhaus, european bauhaus, request, payment request, payment, new european, preliminary assessment, preliminary, milestone, positive preliminary
# Topic 8: western, balkans, western balkans, region, global gateway, request, payment, gateway, payment request, balkan
# Topic 9: bauhaus, european bauhaus, new european, western, ukraine, global gateway, gateway, western balkans, balkans, africa
# Topic 10: bauhaus, european bauhaus, new european, western, emission, gas, methane, balkans, western balkans, agreement
#
# Analyzing with min_df = 0.001 and max_df = 0.5:
# Top words associated with each topic (Count Vectorization):
# Topic 1: plan, ukraine, resilience, recovery, digital, green, climate, transition, economic, recovery resilience
# Topic 2: plan, resilience, recovery, recovery resilience, resilience plan, reform, assessment, rrf, resilience facility, facility
# Topic 3: ukraine, war, russia, ukrainian, russian, financial, assistance, recovery, reform, support ukraine
# Topic 4: cooperation, international, security, canada, continue, partnership, development, ukraine, welcome, commitment
# Topic 5: vaccine, health, covid19, million, africa, dose, pandemic, team, team europe, production
# Topic 6: ukraine, transition, climate, emission, viet, viet nam, nam, hydrogen, energy transition, renewable
# Topic 7: gas, defence, supply, price, market, vaccine, industry, measure, propose, security
# Topic 8: payment, request, climate, target, preliminary, preliminary assessment, payment request, milestone, recovery resilience, emission
# Topic 9: raw, hydrogen, material, raw material, gateway, global gateway, critical, critical raw, chain, strategic
# Topic 10: defence, climate, digital, bauhaus, new european, innovation, european bauhaus, action, social, green
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: ukraine, plan, recovery, resilience, recovery resilience, green, climate, digital, vaccine, reform
# Topic 2: recovery resilience, resilience, recovery, plan, resilience plan, rrf, payment, resilience facility, reform, investment reform
# Topic 3: vaccine, dose, health, africa, covid19, variant, pandemic, vaccination, million dose, covid19 vaccine
# Topic 4: vaccine, ukraine, dose, covid19, health, million, variant, ukrainian, vaccination, million dose
# Topic 5: ukraine, global gateway, partnership, gateway, leyen, der leyen, der, von der, von, development
# Topic 6: gas, hydrogen, request, payment, price, payment request, renewable, russian, vaccine, emission
# Topic 7: request, payment, payment request, bauhaus, european bauhaus, preliminary assessment, preliminary, woman, new european, jewish
# Topic 8: western, balkans, western balkans, china, trade, region, balkan, western balkan, growth plan, agreement
# Topic 9: global gateway, gateway, bauhaus, western, africa, european bauhaus, ukraine, hydrogen, western balkans, balkans
# Topic 10: western, bauhaus, european bauhaus, balkans, western balkans, new european, emission, climate, methane, gas
#
# Analyzing with min_df = 0.001 and max_df = 0.6:
# Top words associated with each topic (Count Vectorization):
# Topic 1: energy, plan, investment, ukraine, global, include, resilience, recovery, billion, climate
# Topic 2: plan, resilience, recovery, recovery resilience, resilience plan, reform, investment, assessment, rrf, resilience facility
# Topic 3: energy, global, climate, transition, partnership, investment, green, emission, renewable, hydrogen
# Topic 4: include, cooperation, ukraine, international, security, continue, canada, global, development, welcome
# Topic 5: vaccine, health, global, world, covid19, pandemic, digital, africa, dose, million
# Topic 6: vaccine, ukraine, africa, million, energy, health, billion, covid19, team, team europe
# Topic 7: gas, vaccine, member states, price, market, defence, supply, energy, measure, covid19
# Topic 8: defence, raw, investment, critical, hydrogen, industry, raw material, material, strategic, critical raw
# Topic 9: payment, request, global, recovery resilience, preliminary, preliminary assessment, recovery, payment request, milestone, resilience
# Topic 10: climate, defence, green, emission, member states, hydrogen, ukraine, innovation, industry, deal
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: ukraine, energy, plan, investment, global, recovery, resilience, recovery resilience, green, climate
# Topic 2: recovery resilience, resilience, recovery, plan, resilience plan, rrf, payment, reform, resilience facility, investment reform
# Topic 3: vaccine, dose, global, health, africa, covid19, variant, pandemic, million dose, vaccination
# Topic 4: vaccine, ukraine, dose, health, covid19, variant, million, vaccination, million dose, ukrainian
# Topic 5: want, know, plan, thank, woman, dear, bauhaus, nextgenerationeu, western, course
# Topic 6: energy, gas, vaccine, price, renewable, russian, hydrogen, dose, supply, russia
# Topic 7: request, payment, payment request, preliminary assessment, preliminary, milestone, positive preliminary, milestone target, efc, target
# Topic 8: western, western balkans, balkans, global gateway, gateway, investment, region, payment, payment request, request
# Topic 9: bauhaus, ukraine, european bauhaus, global gateway, gateway, africa, new european, global, hydrogen, investment
# Topic 10: bauhaus, western, european bauhaus, balkans, western balkans, new european, emission, climate, balkan, western balkan
#
# Analyzing with min_df = 0.01 and max_df = 0.4:
# Top words associated with each topic (Count Vectorization):
# Topic 1: ukraine, resilience, recovery, digital, transition, recovery resilience, reform, russia, security, von
# Topic 2: resilience, recovery, recovery resilience, resilience plan, reform, assessment, digital, rrf, resilience facility, facility
# Topic 3: ukraine, war, russia, ukrainian, recovery, financial, assistance, russian, reform, recovery resilience
# Topic 4: vaccine, health, covid19, africa, dose, pandemic, team, team europe, production, covid19 vaccine
# Topic 5: security, canada, health, development, partnership, ukraine, strengthen, welcome, commitment, sustainable
# Topic 6: hydrogen, ukraine, transition, renewable, emission, clean, africa, gas, financial, energy transition
# Topic 7: gas, defence, supply, vaccine, security, price, russia, china, industry, measure
# Topic 8: raw, defence, material, raw material, critical, critical raw, hydrogen, strategic, digital, chain
# Topic 9: payment, request, preliminary assessment, preliminary, payment request, milestone, positive preliminary, positive, assessment, china
# Topic 10: defence, european defence, bauhaus, new european, european bauhaus, industrial, der, emission, von, von der
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: ukraine, vaccine, russia, recovery, digital, war, resilience, gas, transition, recovery resilience
# Topic 2: recovery resilience, resilience, recovery, resilience plan, rrf, payment, reform, resilience facility, investment reform, assessment
# Topic 3: vaccine, dose, health, africa, covid19, variant, pandemic, vaccination, million dose, global gateway
# Topic 4: vaccine, ukraine, dose, covid19, variant, health, vaccination, million dose, ukrainian, covid19 vaccine
# Topic 5: ukraine, global gateway, gateway, partnership, leyen, der, der leyen, von der, von, development
# Topic 6: gas, price, russian, vaccine, hydrogen, renewable, supply, russia, clean, emission
# Topic 7: western, balkans, western balkans, region, balkan, western balkan, regional market, common regional, growth plan, serbia
# Topic 8: china, agreement, trade, security, zealand, new zealand, ai, council, migration, law
# Topic 9: bauhaus, european bauhaus, western, new european, emission, balkans, western balkans, carbon, methane, conference
# Topic 10: request, payment, payment request, preliminary assessment, preliminary, milestone, bauhaus, positive preliminary, milestone target, efc
#
# Analyzing with min_df = 0.01 and max_df = 0.5:
# Top words associated with each topic (Count Vectorization):
# Topic 1: plan, ukraine, resilience, recovery, digital, green, climate, transition, economic, recovery resilience
# Topic 2: plan, resilience, recovery, recovery resilience, resilience plan, reform, assessment, rrf, resilience facility, facility
# Topic 3: ukraine, war, russia, ukrainian, financial, assistance, russian, recovery, reform, support ukraine
# Topic 4: cooperation, international, security, canada, continue, development, partnership, welcome, commitment, sustainable
# Topic 5: vaccine, health, covid19, million, africa, dose, pandemic, team, team europe, production
# Topic 6: ukraine, transition, climate, hydrogen, emission, green, renewable, africa, financial, clean
# Topic 7: gas, defence, supply, price, market, vaccine, industry, measure, propose, security
# Topic 8: payment, request, preliminary, preliminary assessment, payment request, target, milestone, recovery resilience, climate, assessment
# Topic 9: raw, hydrogen, material, raw material, critical, gateway, global gateway, critical raw, chain, strategic
# Topic 10: defence, climate, bauhaus, new european, european defence, innovation, european bauhaus, industrial, ukraine, digital
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: ukraine, plan, climate, vaccine, recovery, want, green, russia, digital, resilience
# Topic 2: recovery resilience, plan, resilience, recovery, resilience plan, rrf, reform, payment, resilience facility, investment reform
# Topic 3: vaccine, dose, health, africa, covid19, pandemic, variant, vaccination, global gateway, gateway
# Topic 4: vaccine, ukraine, dose, health, covid19, variant, million, vaccination, million dose, covid19 vaccine
# Topic 5: ukraine, global gateway, gateway, partnership, leyen, der leyen, von der, der, von, development
# Topic 6: gas, vaccine, price, russian, renewable, hydrogen, supply, russia, emission, clean
# Topic 7: western, balkans, western balkans, region, global gateway, gateway, balkan, western balkan, common regional, regional market
# Topic 8: china, agreement, trade, ai, security, council, zealand, new zealand, gas, migration
# Topic 9: global gateway, gateway, payment, request, payment request, hydrogen, china, woman, raw, preliminary assessment
# Topic 10: western, payment, request, balkans, western balkans, payment request, preliminary assessment, preliminary, bauhaus, climate
#
# Analyzing with min_df = 0.01 and max_df = 0.6:
# Top words associated with each topic (Count Vectorization):
# Topic 1: energy, plan, investment, ukraine, global, include, resilience, recovery, billion, climate
# Topic 2: plan, resilience, recovery, recovery resilience, resilience plan, reform, investment, assessment, rrf, resilience facility
# Topic 3: ukraine, war, russia, people, ukrainian, recovery, russian, reform, assistance, financial
# Topic 4: include, cooperation, ukraine, international, security, continue, global, canada, development, health
# Topic 5: vaccine, health, global, world, covid19, pandemic, digital, africa, million, dose
# Topic 6: vaccine, ukraine, energy, million, africa, billion, health, covid19, team, team europe
# Topic 7: vaccine, gas, member states, price, market, defence, supply, energy, measure, covid19
# Topic 8: defence, investment, raw, critical, industry, raw material, material, strategic, hydrogen, critical raw
# Topic 9: payment, request, global, recovery resilience, preliminary assessment, preliminary, payment request, recovery, milestone, resilience
# Topic 10: climate, green, defence, emission, hydrogen, member states, ukraine, industry, bauhaus, innovation
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: ukraine, energy, global, investment, plan, climate, vaccine, want, green, recovery
# Topic 2: recovery resilience, plan, resilience, recovery, resilience plan, rrf, reform, payment, resilience facility, investment reform
# Topic 3: vaccine, global, dose, health, africa, global gateway, covid19, gateway, climate, pandemic
# Topic 4: vaccine, ukraine, dose, health, covid19, variant, vaccination, million, million dose, covid19 vaccine
# Topic 5: ukraine, global, global gateway, gateway, partnership, leyen, der leyen, der, von der, von
# Topic 6: gas, energy, vaccine, price, renewable, russian, dose, supply, russia, hydrogen
# Topic 7: global gateway, gateway, investment, africa, ukraine, western, western balkans, balkans, eur, plan
# Topic 8: western, balkans, western balkans, trade, china, agreement, economic, digital, migration, cooperation
# Topic 9: payment, request, global, payment request, china, global gateway, gateway, preliminary assessment, preliminary, russia
# Topic 10: western, balkans, western balkans, payment, bauhaus, request, payment request, european bauhaus, preliminary assessment, energy
#
# Analyzing with min_df = 0.02 and max_df = 0.4:
# Top words associated with each topic (Count Vectorization):
# Topic 1: ukraine, resilience, recovery, digital, transition, recovery resilience, reform, russia, security, von
# Topic 2: resilience, recovery, recovery resilience, resilience plan, reform, assessment, rrf, digital, resilience facility, facility
# Topic 3: ukraine, war, russia, ukrainian, recovery, financial, assistance, reform, russian, recovery resilience
# Topic 4: vaccine, health, covid19, africa, dose, pandemic, team, team europe, production, covid19 vaccine
# Topic 5: security, canada, development, partnership, health, sustainable, strengthen, ukraine, welcome, commitment
# Topic 6: hydrogen, ukraine, transition, renewable, emission, clean, africa, gas, financial, energy transition
# Topic 7: gas, defence, supply, vaccine, price, security, russia, china, measure, industry
# Topic 8: raw, material, raw material, critical, defence, critical raw, hydrogen, strategic, chain, industry
# Topic 9: payment, request, preliminary assessment, preliminary, payment request, milestone, positive preliminary, positive, assessment, target
# Topic 10: agreement, gas, leyen, der leyen, von der, der, von, raw, trade, raw material
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: ukraine, vaccine, russia, recovery, digital, war, gas, resilience, transition, example
# Topic 2: recovery resilience, resilience, recovery, resilience plan, rrf, reform, resilience facility, payment, investment reform, facility
# Topic 3: vaccine, dose, health, africa, covid19, pandemic, variant, vaccination, global gateway, gateway
# Topic 4: vaccine, ukraine, dose, covid19, health, variant, vaccination, million dose, covid19 vaccine, ukrainian
# Topic 5: ukraine, global gateway, gateway, partnership, der, von der, der leyen, leyen, von, development
# Topic 6: gas, vaccine, hydrogen, russian, renewable, price, russia, supply, clean, emission
# Topic 7: western, western balkans, balkans, global gateway, gateway, region, eur, balkan, western balkan, regional market
# Topic 8: hydrogen, global gateway, gateway, ukraine, africa, bauhaus, european bauhaus, project, new european, city
# Topic 9: bauhaus, western, european bauhaus, western balkans, balkans, emission, new european, gas, carbon, conference
# Topic 10: woman, request, payment, payment request, preliminary assessment, preliminary, africa, milestone, global gateway, positive preliminary
#
# Analyzing with min_df = 0.02 and max_df = 0.5:
# Top words associated with each topic (Count Vectorization):
# Topic 1: plan, ukraine, resilience, recovery, digital, green, climate, transition, economic, recovery resilience
# Topic 2: plan, resilience, recovery, recovery resilience, resilience plan, reform, assessment, rrf, resilience facility, facility
# Topic 3: ukraine, war, russia, ukrainian, financial, assistance, russian, recovery, reform, support ukraine
# Topic 4: cooperation, international, security, continue, canada, development, partnership, health, welcome, commitment
# Topic 5: vaccine, health, covid19, million, africa, dose, pandemic, team, team europe, production
# Topic 6: ukraine, transition, climate, hydrogen, emission, green, renewable, africa, financial, clean
# Topic 7: gas, defence, supply, price, market, vaccine, measure, industry, propose, security
# Topic 8: payment, request, preliminary, preliminary assessment, payment request, milestone, recovery resilience, target, assessment, recovery
# Topic 9: raw, material, raw material, hydrogen, critical, gateway, global gateway, critical raw, chain, strategic
# Topic 10: defence, climate, ukraine, bauhaus, innovation, new european, industry, european bauhaus, industrial, technology
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: ukraine, plan, climate, vaccine, want, russia, green, recovery, digital, know
# Topic 2: recovery resilience, plan, resilience, recovery, resilience plan, rrf, reform, resilience facility, payment, investment reform
# Topic 3: vaccine, dose, health, africa, covid19, pandemic, variant, global gateway, gateway, climate
# Topic 4: vaccine, ukraine, dose, health, covid19, variant, vaccination, million, million dose, covid19 vaccine
# Topic 5: ukraine, global gateway, gateway, partnership, der leyen, von der, der, leyen, von, development
# Topic 6: gas, vaccine, russian, price, hydrogen, renewable, russia, supply, emission, clean
# Topic 7: western, western balkans, balkans, global gateway, gateway, region, eur, balkan, western balkan, regional market
# Topic 8: ukraine, global gateway, gateway, africa, hydrogen, bauhaus, project, european bauhaus, green, million
# Topic 9: western, western balkans, balkans, bauhaus, emission, climate, european bauhaus, new european, plan, assistance
# Topic 10: payment, request, payment request, preliminary assessment, western, preliminary, climate, western balkans, balkans, milestone
#
# Analyzing with min_df = 0.02 and max_df = 0.6:
# Top words associated with each topic (Count Vectorization):
# Topic 1: energy, plan, investment, ukraine, global, include, resilience, recovery, billion, climate
# Topic 2: plan, resilience, recovery, recovery resilience, resilience plan, reform, investment, assessment, rrf, resilience facility
# Topic 3: ukraine, war, russia, people, ukrainian, recovery, russian, assistance, reform, financial
# Topic 4: include, cooperation, ukraine, international, security, global, continue, canada, development, health
# Topic 5: vaccine, health, global, world, covid19, pandemic, digital, africa, million, dose
# Topic 6: vaccine, energy, ukraine, million, africa, billion, health, covid19, team, team europe
# Topic 7: vaccine, gas, member states, price, market, supply, energy, defence, measure, covid19
# Topic 8: defence, investment, raw, critical, raw material, industry, material, strategic, critical raw, hydrogen
# Topic 9: payment, request, global, recovery resilience, preliminary assessment, preliminary, payment request, milestone, resilience, recovery
# Topic 10: climate, green, defence, emission, hydrogen, member states, ukraine, industry, innovation, deal
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: ukraine, energy, global, investment, plan, climate, want, vaccine, green, russia
# Topic 2: recovery resilience, plan, resilience, recovery, resilience plan, rrf, reform, resilience facility, payment, investment reform
# Topic 3: ukraine, russia, war, ukrainian, russian, putin, sanction, support ukraine, reconstruction, reform
# Topic 4: vaccine, dose, ukraine, health, covid19, variant, vaccination, million, million dose, covid19 vaccine
# Topic 5: ukraine, global, global gateway, gateway, partnership, von der, leyen, der leyen, der, von
# Topic 6: energy, gas, vaccine, price, russian, renewable, dose, supply, russia, hydrogen
# Topic 7: global gateway, gateway, investment, ukraine, africa, western, global, eur, western balkans, balkans
# Topic 8: western, balkans, western balkans, trade, china, agreement, economic, region, cooperation, migration
# Topic 9: western, bauhaus, western balkans, balkans, european bauhaus, new european, plan, social, assistance, energy
# Topic 10: western, payment, request, payment request, energy, balkans, western balkans, woman, global, preliminary assessment

# %%
print("White House Top words associated with each topic Count Vectorization and TF-IDF Vectorization:")
for min_df in min_df_values:
    for max_df in max_df_values:
        # Print the current combination of min_df and max_df being analyzed
        print(f"\nAnalyzing with min_df = {min_df} and max_df = {max_df}:")
        
        # Call the analyze_text_data function for the current combination
        analyze_text_data(WH_data, min_df, max_df)
# Out:
# White House Top words associated with each topic Count Vectorization and TF-IDF Vectorization:
#
# Analyzing with min_df = 0.001 and max_df = 0.4:
# Top words associated with each topic (Count Vectorization):
# Topic 1: say, think, want, look, question, talk, ahead, plan, sure, thing
# Topic 2: health, program, care, investment, energy, climate, law, access, federal, billion
# Topic 3: applause, job, pay, cost, say, drug, inflation, laughter, act, folk
# Topic 4: energy, climate, ukraine, russia, global, clean, international, technology, action, clean energy
# Topic 5: serve, law, university, school, department, member, service, district, court, justice
# Topic 6: care, tweet, cost, ahead, drug, act, inflation, health, americans, price
# Topic 7: law, university, serve, vaccine, drug, inflation, energy, reduction, inflation reduction, reduction act
# Topic 8: health, care, tweet, ukraine, drug, applause, global, mental, mental health, woman
# Topic 9: term, russia, ukraine, price, release, supervised, think, year term, sentence, serve
# Topic 10: care, member, jen, child, climate, forward, think, worker, tweet, job
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: say, think, want, applause, look, question, talk, thing, ahead, mean
# Topic 2: energy, serve, federal, health, climate, department, university, program, development, global
# Topic 3: applause, job, pay, laughter, care, child, law, school, folk, federal
# Topic 4: federal, fema, vaccine, emergency, fema news, federal funding, vaccinate, funding available, sharing basis, cost sharing
# Topic 5: applause, ukraine, fema, fema news, emergency, federal, russia, federal funding, funding available, sharing basis
# Topic 6: serve, university, nominee, district, assistant, director, judge, member, board, vice
# Topic 7: vaccine, applause, vaccinate, vaccination, covid19, health, dr, dose, variant, shot
# Topic 8: national emergency, executive order, emergency, executive, continue effect, declare executive, anniversary date, notice state, federal register, order
# Topic 9: care, health, woman, violence, gun, ukraine, reproductive, health care, access, abortion
# Topic 10: ukraine, russia, russian, nato, sullivan, cost, price, putin, drug, vaccine
#
# Analyzing with min_df = 0.001 and max_df = 0.5:
# Top words associated with each topic (Count Vectorization):
# Topic 1: know, say, think, right, want, look, time, question, thank, talk
# Topic 2: health, community, program, million, care, investment, energy, provide, climate, access
# Topic 3: applause, america, job, pay, know, laughter, family, cost, folk, drug
# Topic 4: energy, climate, security, ukraine, global, russia, clean, economic, technology, international
# Topic 5: vaccine, thank, global, world, climate, vaccinate, applause, think, covid19, supply
# Topic 6: cost, inflation, drug, tweet, price, care, act, energy, reduction, inflation reduction
# Topic 7: health, care, tweet, family, drug, ukraine, security, mental, child, mental health
# Topic 8: law, serve, university, vaccine, drug, inflation, energy, reduction, inflation reduction, reduction act
# Topic 9: russia, ukraine, term, serve, child, tax, price, pay, plan, putin
# Topic 10: thank, ukraine, community, russia, senior, program, senior administration, official, administration official, provide
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: know, say, think, thank, applause, want, right, look, question, talk
# Topic 2: security, energy, climate, health, federal, serve, department, program, global, development
# Topic 3: applause, america, job, community, pay, care, family, child, million, federal
# Topic 4: federal, fema, vaccine, emergency, fema news, vaccinate, question, federal funding, vaccination, funding available
# Topic 5: applause, fema, fema news, federal, emergency, federal funding, funding available, sharing basis, ukraine, cost sharing
# Topic 6: serve, university, nominee, assistant, district, director, judge, member, board, deputy
# Topic 7: vaccine, applause, vaccinate, vaccination, covid19, dr, health, thank, dose, variant
# Topic 8: national emergency, executive order, emergency, executive, continue effect, declare executive, anniversary date, notice state, federal register, order
# Topic 9: care, woman, health, right, reproductive, violence, gun, health care, access, ukraine
# Topic 10: ukraine, russia, sullivan, nato, russian, cost, price, drug, mr sullivan, putin
#
# Analyzing with min_df = 0.001 and max_df = 0.6:
# Top words associated with each topic (Count Vectorization):
# Topic 1: know, say, think, right, want, look, time, question, thank, continue
# Topic 2: health, community, support, program, new, million, care, investment, energy, provide
# Topic 3: applause, america, job, know, pay, family, laughter, cost, folk, drug
# Topic 4: energy, climate, security, ukraine, global, clean, russia, support, economic, investment
# Topic 5: vaccine, thank, country, global, world, vaccinate, applause, covid19, vaccination, think
# Topic 6: cost, inflation, tweet, drug, care, price, act, reduction, energy, continue
# Topic 7: health, care, child, family, support, applause, ukraine, mental, right, woman
# Topic 8: drug, serve, tweet, vaccine, law, university, inflation, cost, act, inflation reduction
# Topic 9: child, serve, tax, russia, american, plan, ukraine, term, pay, family
# Topic 10: say, global, applause, law, house, ahead, continue, support, school, vaccine
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: know, say, think, thank, want, applause, right, look, question, talk
# Topic 2: security, energy, national, health, climate, support, federal, serve, department, program
# Topic 3: applause, america, job, community, care, pay, family, child, million, federal
# Topic 4: federal, fema, vaccine, emergency, fema news, question, vaccinate, federal funding, state, funding available
# Topic 5: applause, fema, federal, emergency, fema news, serve, security, federal funding, laughter, sharing basis
# Topic 6: serve, university, nominee, assistant, director, district, member, board, judge, deputy
# Topic 7: vaccine, applause, vaccinate, vaccination, covid19, health, dr, thank, dose, variant
# Topic 8: national emergency, executive order, emergency, continue effect, executive, declare executive, anniversary date, notice state, national, federal register
# Topic 9: woman, care, health, right, reproductive, violence, gun, health care, ukraine, access
# Topic 10: ukraine, russia, sullivan, cost, drug, price, nato, russian, pay, mr sullivan
#
# Analyzing with min_df = 0.01 and max_df = 0.4:
# Top words associated with each topic (Count Vectorization):
# Topic 1: say, think, want, look, question, talk, ahead, plan, sure, thing
# Topic 2: health, program, care, investment, energy, climate, law, access, federal, billion
# Topic 3: applause, job, pay, cost, say, drug, inflation, laughter, act, folk
# Topic 4: energy, climate, ukraine, russia, global, clean, international, technology, action, clean energy
# Topic 5: law, serve, university, school, department, member, service, district, court, justice
# Topic 6: care, cost, tweet, ahead, drug, act, inflation, health, price, americans
# Topic 7: law, university, vaccine, serve, inflation, drug, energy, reduction, climate, inflation reduction
# Topic 8: health, care, tweet, drug, ukraine, global, applause, mental, mental health, russia
# Topic 9: russia, ukraine, price, think, term, senior, child, cost, drug, serve
# Topic 10: care, member, climate, jen, think, child, worker, forward, tweet, certainly
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: say, think, applause, want, look, talk, question, thing, ukraine, job
# Topic 2: energy, climate, serve, global, discuss, cooperation, sullivan, department, health, development
# Topic 3: ukraine, russia, question, minister, sullivan, prime minister, prime, nato, think, say
# Topic 4: applause, laughter, minister, sullivan, prime minister, prime, vice, pacific, cooperation, mr
# Topic 5: serve, university, nominee, assistant, director, district, member, board, deputy, vice
# Topic 6: applause, fema, federal, emergency, fema news, federal funding, funding available, sharing basis, biden jr, joseph biden
# Topic 7: vaccine, applause, vaccinate, covid19, health, vaccination, dose, dr, shot, variant
# Topic 8: national emergency, executive order, ukraine, executive, order, declare executive, violence, woman, emergency, continue effect
# Topic 9: ukraine, sullivan, russia, mr sullivan, security advisor, advisor, care, advisor jake, jake sullivan, cost
# Topic 10: sullivan, national emergency, mr sullivan, national security, mr, vaccine, emergency, executive order, declare executive, continue effect
#
# Analyzing with min_df = 0.01 and max_df = 0.5:
# Top words associated with each topic (Count Vectorization):
# Topic 1: know, say, think, right, want, look, time, question, thank, talk
# Topic 2: health, community, program, million, care, investment, energy, provide, climate, access
# Topic 3: applause, america, job, pay, know, laughter, family, cost, folk, drug
# Topic 4: energy, climate, security, ukraine, global, russia, clean, economic, technology, international
# Topic 5: vaccine, thank, global, world, climate, vaccinate, applause, think, covid19, supply
# Topic 6: cost, inflation, drug, tweet, price, energy, act, reduction, care, inflation reduction
# Topic 7: health, care, tweet, family, ukraine, child, security, drug, mental, mental health
# Topic 8: law, serve, university, drug, vaccine, inflation, reduction, inflation reduction, reduction act, cost
# Topic 9: ukraine, russia, serve, child, tax, price, pay, term, plan, putin
# Topic 10: ukraine, thank, community, russia, senior, program, senior administration, official, administration official, provide
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: know, say, think, thank, applause, want, right, look, talk, time
# Topic 2: security, energy, climate, global, discuss, cooperation, serve, sullivan, health, economic
# Topic 3: applause, community, federal, serve, health, job, america, care, program, million
# Topic 4: vaccine, question, federal, fema, vaccinate, emergency, ahead, vaccination, fema news, certainly
# Topic 5: serve, university, nominee, assistant, director, district, member, board, vice, deputy
# Topic 6: applause, fema, federal, emergency, fema news, federal funding, funding available, sharing basis, cost sharing, biden jr
# Topic 7: vaccine, vaccinate, health, covid19, vaccination, applause, dose, dr, thank, woman
# Topic 8: national emergency, ukraine, executive order, care, violence, executive, woman, gun, act, right
# Topic 9: sullivan, ukraine, mr sullivan, security advisor, advisor, mr, advisor jake, jake sullivan, jake, russia
# Topic 10: national emergency, executive order, emergency, vaccine, declare executive, continue effect, federal register, sullivan, executive, national security
#
# Analyzing with min_df = 0.01 and max_df = 0.6:
# Top words associated with each topic (Count Vectorization):
# Topic 1: know, say, think, right, want, look, time, question, thank, continue
# Topic 2: health, community, support, program, new, million, care, investment, energy, provide
# Topic 3: applause, america, job, know, pay, family, laughter, cost, folk, drug
# Topic 4: energy, climate, security, ukraine, global, clean, russia, support, economic, investment
# Topic 5: vaccine, thank, country, global, world, vaccinate, applause, covid19, vaccination, think
# Topic 6: cost, inflation, drug, tweet, price, care, act, energy, reduction, inflation reduction
# Topic 7: care, health, child, support, family, ukraine, applause, mental, woman, right
# Topic 8: drug, tweet, serve, vaccine, university, law, inflation, cost, health, act
# Topic 9: child, serve, american, russia, tax, ukraine, plan, pay, university, member
# Topic 10: say, global, applause, house, support, continue, ahead, law, school, vaccine
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: know, say, think, thank, applause, want, right, look, talk, time
# Topic 2: security, national, support, energy, climate, discuss, global, cooperation, serve, sullivan
# Topic 3: applause, community, federal, serve, health, job, america, care, program, university
# Topic 4: vaccine, question, federal, fema, emergency, vaccinate, ahead, vaccination, fema news, certainly
# Topic 5: serve, university, nominee, assistant, director, district, member, board, vice, deputy
# Topic 6: applause, fema, federal, emergency, fema news, federal funding, funding available, sharing basis, cost sharing, joseph biden
# Topic 7: vaccine, vaccinate, health, covid19, vaccination, applause, dr, dose, woman, thank
# Topic 8: national emergency, executive order, national, ukraine, executive, care, continue, act, declare executive, violence
# Topic 9: sullivan, mr sullivan, security advisor, mr, national security, advisor, vaccine, national, advisor jake, jake sullivan
# Topic 10: national emergency, executive order, emergency, executive, declare executive, continue effect, order, federal register, national, declare
#
# Analyzing with min_df = 0.02 and max_df = 0.4:
# Top words associated with each topic (Count Vectorization):
# Topic 1: say, think, want, look, question, talk, ahead, plan, sure, thing
# Topic 2: health, program, care, investment, energy, climate, law, access, federal, billion
# Topic 3: applause, job, pay, cost, say, laughter, drug, inflation, act, folk
# Topic 4: energy, climate, ukraine, russia, global, clean, international, technology, clean energy, investment
# Topic 5: law, serve, university, school, department, member, service, justice, court, district
# Topic 6: care, cost, ahead, drug, inflation, act, price, plan, americans, inflation reduction
# Topic 7: law, vaccine, energy, university, serve, climate, inflation, reduction, inflation reduction, reduction act
# Topic 8: health, drug, care, price, ukraine, medicare, cost, act, global, senior
# Topic 9: russia, ukraine, price, think, senior, cost, drug, term, putin, sanction
# Topic 10: care, member, think, child, jen, climate, worker, forward, policy, serve
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: say, think, applause, want, look, talk, question, thing, ukraine, job
# Topic 2: applause, say, think, want, talk, thing, laughter, look, mean, lot
# Topic 3: ukraine, russia, minister, sullivan, prime minister, prime, discuss, nato, think, question
# Topic 4: applause, laughter, vice, minister, prime minister, sullivan, prime, vice president, mr, cooperation
# Topic 5: serve, university, nominee, assistant, director, district, member, board, vice, deputy
# Topic 6: fema, federal, emergency, applause, federal funding, biden jr, joseph biden, assistance, joseph, funding available
# Topic 7: vaccine, health, vaccinate, covid19, vaccination, applause, dose, dr, woman, care
# Topic 8: ukraine, russia, care, health, russian, sullivan, health care, woman, violence, gun
# Topic 9: sullivan, mr sullivan, mr, security advisor, advisor, national security, advisor jake, jake sullivan, jake, vaccine
# Topic 10: ukraine, russia, vaccine, applause, vaccinate, nato, russian, serve, vaccination, university
#
# Analyzing with min_df = 0.02 and max_df = 0.5:
# Top words associated with each topic (Count Vectorization):
# Topic 1: know, say, think, right, want, look, time, question, thank, talk
# Topic 2: health, community, program, million, care, investment, energy, provide, climate, access
# Topic 3: applause, america, job, know, pay, laughter, family, folk, cost, drug
# Topic 4: energy, climate, security, ukraine, global, russia, clean, economic, technology, international
# Topic 5: vaccine, thank, global, world, vaccinate, covid19, climate, think, applause, vaccination
# Topic 6: cost, inflation, drug, price, energy, act, reduction, inflation reduction, reduction act, care
# Topic 7: care, health, child, family, ukraine, mental, security, mental health, woman, right
# Topic 8: drug, law, serve, university, vaccine, inflation, cost, price, act, reduction
# Topic 9: ukraine, russia, serve, tax, child, pay, price, putin, plan, university
# Topic 10: thank, ukraine, community, russia, senior, program, senior administration, official, administration official, drug
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: know, say, think, thank, applause, want, right, look, talk, time
# Topic 2: security, discuss, energy, cooperation, global, climate, sullivan, serve, economic, health
# Topic 3: applause, community, federal, serve, health, university, program, care, million, job
# Topic 4: applause, america, laughter, thank, world, nation, vice, minister, pacific, vice president
# Topic 5: serve, university, nominee, assistant, director, district, member, vice, board, deputy
# Topic 6: applause, fema, federal, emergency, federal funding, biden jr, joseph biden, funding available, joseph, assistance
# Topic 7: vaccine, health, vaccinate, covid19, vaccination, applause, dose, dr, woman, care
# Topic 8: ukraine, care, russia, sullivan, health, family, health care, gun, violence, woman
# Topic 9: sullivan, mr sullivan, mr, security advisor, advisor, national security, vaccine, advisor jake, jake sullivan, jake
# Topic 10: ukraine, russia, vaccine, russian, nato, world, serve, putin, applause, vaccinate
#
# Analyzing with min_df = 0.02 and max_df = 0.6:
# Top words associated with each topic (Count Vectorization):
# Topic 1: know, say, think, right, want, look, time, question, thank, continue
# Topic 2: health, community, support, program, new, million, care, investment, energy, provide
# Topic 3: applause, america, job, know, pay, laughter, family, folk, cost, drug
# Topic 4: energy, climate, security, ukraine, global, clean, russia, support, economic, investment
# Topic 5: vaccine, thank, country, global, vaccinate, world, covid19, vaccination, applause, dose
# Topic 6: cost, inflation, drug, price, energy, care, act, reduction, plan, inflation reduction
# Topic 7: care, health, child, support, family, ukraine, applause, mental, woman, mental health
# Topic 8: drug, health, cost, inflation, vaccine, price, act, serve, university, medicare
# Topic 9: russia, child, ukraine, serve, american, tax, plan, pay, university, family
# Topic 10: administration, thank, senior, senior administration, official, administration official, think, really, know, community
#
# Top words associated with each topic (TF-IDF Vectorization):
# Topic 1: know, say, thank, think, applause, want, right, look, talk, time
# Topic 2: security, national, support, discuss, cooperation, energy, global, sullivan, climate, serve
# Topic 3: applause, community, federal, serve, health, university, program, care, million, job
# Topic 4: applause, america, laughter, world, nation, thank, climate, vice, pacific, cooperation
# Topic 5: serve, university, nominee, assistant, director, district, vice, member, board, deputy
# Topic 6: applause, fema, federal, emergency, federal funding, biden jr, joseph biden, funding available, joseph, assistance
# Topic 7: vaccine, health, vaccinate, covid19, vaccination, woman, dose, applause, dr, care
# Topic 8: sullivan, ukraine, care, mr sullivan, security advisor, national security, advisor, health, russia, family
# Topic 9: sullivan, mr sullivan, mr, security advisor, national security, advisor, vaccine, advisor jake, jake sullivan, security
# Topic 10: ukraine, russia, vaccine, nato, russian, serve, vaccinate, university, putin, vaccination

# %% [markdown]
# ## LDA and topics analysis

# %%
def analyze_text_with_lda(data, min_df, max_df):
    # Initialize CountVectorizer
    cv = CountVectorizer(ngram_range=(1, 2), lowercase=False, min_df=min_df, max_df=max_df)
    
    # Fit CountVectorizer and transform text data
    cv.fit(data.text_preproc)
    vectorized_text = cv.transform(data.text_preproc).toarray()
    vectorized_title = cv.transform(data.titles_preproc).toarray()

    # Combine text and title vectorized data with specified weight
    dtm = 2 * vectorized_title + vectorized_text

    # Convert the combined DTM to a sparse format for gensim
    dtm_sparse = csr_matrix(dtm)

    # Convert sparse matrix to gensim corpus
    corpus = Sparse2Corpus(dtm_sparse, documents_columns=False)

    # Create a Gensim dictionary from the CountVectorizer vocabulary
    dictionary = Dictionary()
    cv_vocabulary = {id_: token for token, id_ in cv.vocabulary_.items()}
    # Manually populate the Dictionary object
    dictionary.id2token = cv_vocabulary
    dictionary.token2id = {token: id_ for id_, token in cv_vocabulary.items()}

    # Hardcoded parameters for LDA
    num_topics = 10
    passes = 10
    random_state = 10

    # Build LDA model
    lda_model = models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, passes=passes, random_state=random_state)

    # Display the topics
    print("Top words associated with each topic (LDA):")
    topics = lda_model.show_topics(num_words=10, formatted=False)
    for topic_num, topic_words in topics:
        words = ', '.join([word for word, _ in topic_words])
        print(f"Topic {topic_num + 1}: {words}")

    return lda_model, corpus

# %%
# Define the range of min_df and max_df values
min_df_values = [0.001, 0.01, 0.02, 0.1]
max_df_values = [0.3, 0.4, 0.5, 0.6]

# Iterate through each combination of min_df and max_df values
print("European Commission Top words associated with each topic with LDA:")
for min_df in min_df_values:
    for max_df in max_df_values:
        # Print the current combination of min_df and max_df being analyzed
        print(f"\nAnalyzing with min_df = {min_df} and max_df = {max_df}:")
        
        # Call the analyze_text_data function for the current combination
        analyze_text_with_lda(EC_data, min_df, max_df)
# Out:
# European Commission Top words associated with each topic Count Vectorization and TF-IDF Vectorization:
#
# Analyzing with min_df = 0.001 and max_df = 0.4:
# Top words associated with each topic (LDA):
# Topic 1: resilience, recovery, recovery resilience, resilience plan, digital, reform, measure, transition, RRF, NextGenerationEU
# Topic 2: gateway, global gateway, africa, partnership, raw, development, sustainable, team, raw material, material
# Topic 3: ukraine, western, financial, assistance, balkans, western balkans, ukrainian, war, reform, russia
# Topic 4: ukraine, digital, von, der leyen, leyen, von der, der, example, president von, change
# Topic 5: vaccine, health, dose, von, von der, leyen, der leyen, der, pandemic, president von
# Topic 6: ukraine, woman, defence, der, von der, der leyen, von, leyen, security, president von
# Topic 7: ukraine, russia, russian, war, gas, china, sanction, der leyen, von der, der
# Topic 8: hydrogen, partnership, transition, emission, clean, renewable, agreement, carbon, canada, action
# Topic 9: bauhaus, new european, european bauhaus, forest, methane, von, der, der leyen, leyen, von der
# Topic 10: recovery, resilience, recovery resilience, vaccine, payment, request, assessment, reform, resilience plan, facility
#
# Analyzing with min_df = 0.001 and max_df = 0.5:
# Top words associated with each topic (LDA):
# Topic 1: health, HERA, vaccine, want, pandemic, emergency, know, woman, crisis, market
# Topic 2: plan, digital, recovery, social, resilience, green, recovery resilience, million, NextGenerationEU, council
# Topic 3: ukraine, international, cooperation, partnership, security, russia, leyen, der, der leyen, von der
# Topic 4: want, climate, trade, green, change, must, know, president von, der leyen, von
# Topic 5: vaccine, recovery, resilience, recovery resilience, payment, request, assessment, million, plan, facility
# Topic 6: climate, agreement, conference, von der, der, von, der leyen, leyen, renewable, migration
# Topic 7: climate, green, plan, africa, transition, emission, project, sustainable, team, von der
# Topic 8: ukraine, russia, know, gas, war, market, want, president von, russian, von
# Topic 9: vaccine, million, health, gateway, global gateway, von, der, von der, der leyen, leyen
# Topic 10: plan, resilience, recovery, recovery resilience, reform, resilience plan, measure, digital, green, transition
#
# Analyzing with min_df = 0.001 and max_df = 0.6:
# Top words associated with each topic (LDA):
# Topic 1: ukraine, hydrogen, energy, tunisia, russia, clean, crime, international, project, include
# Topic 2: ukraine, want, people, know, one, thank, good, see, energy, much
# Topic 3: energy, emission, climate, transition, global, western, methane, investment, western balkans, balkans
# Topic 4: plan, recovery, resilience, recovery resilience, investment, reform, resilience plan, billion, digital, energy
# Topic 5: ukraine, defence, billion, assistance, financial, million, ukrainian, member states, russia, people
# Topic 6: energy, global, investment, partnership, climate, cooperation, gateway, global gateway, green, ukraine
# Topic 7: trade, global, agreement, climate, economic, china, include, digital, security, green
# Topic 8: woman, gender, equality, equal, social, pay, day, violence, gender equality, right
# Topic 9: vaccine, health, global, million, dose, COVID19, pandemic, world, member states, von der
# Topic 10: hydrogen, global, green, digital, clean, energy, climate, investment, economy, von der
#
# Analyzing with min_df = 0.01 and max_df = 0.4:
# Top words associated with each topic (LDA):
# Topic 1: ukraine, russia, war, russian, der, leyen, von, von der, der leyen, president von
# Topic 2: defence, agreement, AI, digital, framework, act, joint, law, risk, council
# Topic 3: trade, partnership, global gateway, gateway, agreement, digital, sustainable, von der, der, der leyen
# Topic 4: resilience, recovery, recovery resilience, resilience plan, reform, digital, facility, resilience facility, RRF, assessment
# Topic 5: vaccine, dose, COVID19, vaccination, variant, pandemic, health, million dose, der leyen, deliver
# Topic 6: transition, gas, renewable, supply, emission, clean, security, raw, industry, reduce
# Topic 7: ukraine, financial, assistance, reform, ukrainian, moldova, war, reconstruction, support ukraine, russia
# Topic 8: must, change, clean, example, speech, president von, hydrogen, let, von, der
# Topic 9: health, africa, western, vaccine, western balkans, balkans, region, pandemic, von, leyen
# Topic 10: recovery, NextGenerationEU, project, von der, deal, green deal, european green, der, leyen, von
#
# Analyzing with min_df = 0.01 and max_df = 0.5:
# Top words associated with each topic (LDA):
# Topic 1: ukraine, security, gas, cooperation, supply, joint, economic, market, russia, trade
# Topic 2: plan, resilience, recovery, recovery resilience, digital, resilience plan, reform, measure, green, transition
# Topic 3: social, der leyen, der, leyen, von der, von, young, change, president von, conference
# Topic 4: climate, green, clean, hydrogen, want, emission, project, transition, market, industry
# Topic 5: ukraine, russia, war, want, must, russian, know, president von, von, der
# Topic 6: agreement, million, vaccine, european commission, climate, international, development, ensure, provide, food
# Topic 7: vaccine, health, pandemic, africa, plan, dose, der, der leyen, leyen, von der
# Topic 8: recovery, resilience, plan, recovery resilience, reform, resilience plan, payment, facility, NextGenerationEU, request
# Topic 9: partnership, transition, gateway, global gateway, partner, renewable, raw, region, summit, cooperation
# Topic 10: digital, bauhaus, european bauhaus, new european, ukraine, moldova, AI, council, reform, declaration
#
# Analyzing with min_df = 0.01 and max_df = 0.6:
# Top words associated with each topic (LDA):
# Topic 1: energy, include, ukraine, cooperation, security, economic, international, global, partnership, continue
# Topic 2: people, future, life, must, want, one, democracy, right, woman, time
# Topic 3: vaccine, health, dose, COVID19, pandemic, member states, global, million, variant, vaccination
# Topic 4: want, global, energy, thank, world, know, important, good, much, investment
# Topic 5: ukraine, russia, war, ukrainian, russian, people, million, billion, der leyen, der
# Topic 6: digital, global, million, AI, international, member states, act, raw, world, team
# Topic 7: global, investment, gateway, global gateway, leyen, von der, der leyen, der, von, green
# Topic 8: plan, recovery, resilience, recovery resilience, investment, resilience plan, reform, billion, digital, NextGenerationEU
# Topic 9: energy, climate, green, hydrogen, clean, investment, transition, industry, emission, renewable
# Topic 10: gas, energy, price, member states, market, supply, demand, russian, social, electricity
#
# Analyzing with min_df = 0.02 and max_df = 0.4:
# Top words associated with each topic (LDA):
# Topic 1: hydrogen, gas, renewable, clean, supply, project, partnership, raw, methane, renewable energy
# Topic 2: ukraine, financial, assistance, der leyen, der, leyen, von, von der, global gateway, gateway
# Topic 3: agreement, digital, council, trade, parliament, proposal, citizen, european parliament, framework, measure
# Topic 4: ukraine, russia, war, russian, gas, price, food, putin, ukrainian, must
# Topic 5: ukraine, western, russia, reform, war, der leyen, von, balkans, leyen, von der
# Topic 6: vaccine, health, dose, africa, COVID19, pandemic, team, team europe, production, vaccination
# Topic 7: president von, der, von, example, der leyen, leyen, von der, dear, must, course
# Topic 8: security, china, trade, joint, digital, defence, partnership, canada, ukraine, russia
# Topic 9: resilience, recovery, recovery resilience, resilience plan, reform, digital, facility, NextGenerationEU, assessment, resilience facility
# Topic 10: transition, emission, clean, carbon, industry, woman, zero, target, net, 2030
#
# Analyzing with min_df = 0.02 and max_df = 0.5:
# Top words associated with each topic (LDA):
# Topic 1: ukraine, war, want, russia, president von, know, von, von der, leyen, der leyen
# Topic 2: social, digital, education, programme, der leyen, leyen, der, von der, von, AI
# Topic 3: climate, security, cooperation, partnership, transition, international, economic, agreement, joint, defence
# Topic 4: recovery, resilience, recovery resilience, payment, request, plan, assessment, reform, facility, milestone
# Topic 5: vaccine, health, gateway, global gateway, partnership, africa, million, development, partner, leyen
# Topic 6: gas, russia, russian, price, ukraine, bauhaus, new european, european bauhaus, der, leyen
# Topic 7: plan, resilience, recovery, recovery resilience, resilience plan, reform, digital, green, transition, measure
# Topic 8: ukraine, million, financial, assistance, international, provide, russia, der leyen, measure, von
# Topic 9: china, change, digital, woman, trade, want, right, like, climate, must
# Topic 10: climate, green, market, clean, want, hydrogen, know, course, much, example
#
# Analyzing with min_df = 0.02 and max_df = 0.6:
# Top words associated with each topic (LDA):
# Topic 1: vaccine, health, global, dose, pandemic, COVID19, million, member states, africa, world
# Topic 2: ukraine, member states, energy, financial, billion, assistance, security, million, provide, include
# Topic 3: people, woman, der leyen, von der, der, von, leyen, president von, life, thank
# Topic 4: climate, global, green, change, emission, climate change, world, biodiversity, want, carbon
# Topic 5: economic, western, ukraine, cooperation, balkans, western balkans, reform, important, investment, include
# Topic 6: plan, green, investment, social, market, economy, know, recovery, NextGenerationEU, example
# Topic 7: plan, resilience, recovery, recovery resilience, investment, resilience plan, reform, billion, digital, facility
# Topic 8: digital, agreement, bauhaus, new european, european bauhaus, trade, AI, future, people, der
# Topic 9: ukraine, russia, war, energy, world, one, want, russian, people, time
# Topic 10: energy, global, investment, partnership, hydrogen, transition, climate, gateway, global gateway, renewable

# %%
# Define the range of min_df and max_df values
min_df_values = [0.001, 0.01, 0.02, 0.1]
max_df_values = [0.3, 0.4, 0.5, 0.6]

# Iterate through each combination of min_df and max_df values
print("European Commission Top words associated with each topic Count Vectorization and TF-IDF Vectorization:")
for min_df in min_df_values:
    for max_df in max_df_values:
        # Print the current combination of min_df and max_df being analyzed
        print(f"\nAnalyzing with min_df = {min_df} and max_df = {max_df}:")
        
        # Call the analyze_text_data function for the current combination
        analyze_text_with_lda(WH_data, min_df, max_df)

# %%
#We choose one lda and then role it, this is for text purposes
lda_model_ECB, corpus_ECB = analyze_text_with_lda(EC_data, 0.02, 0.6)
lda_model_WH, corpus_WH = analyze_text_with_lda(WH_data, 0.02, 0.6)
# Out:
# Top words associated with each topic (LDA):
# Topic 1: vaccine, health, global, dose, pandemic, COVID19, million, member states, africa, world
# Topic 2: ukraine, member states, energy, financial, billion, assistance, security, million, provide, include
# Topic 3: people, woman, der leyen, von der, der, von, leyen, president von, life, thank
# Topic 4: climate, global, green, change, emission, climate change, world, biodiversity, want, carbon
# Topic 5: economic, western, ukraine, cooperation, balkans, western balkans, reform, important, investment, include
# Topic 6: plan, green, investment, social, market, economy, know, recovery, NextGenerationEU, example
# Topic 7: plan, resilience, recovery, recovery resilience, investment, resilience plan, reform, billion, digital, facility
# Topic 8: digital, agreement, bauhaus, new european, european bauhaus, trade, AI, future, people, der
# Topic 9: ukraine, russia, war, energy, world, one, want, russian, people, time
# Topic 10: energy, global, investment, partnership, hydrogen, transition, climate, gateway, global gateway, renewable

# %%
def aggregate_topic_shares(data, lda_model, corpus):
    # Get document topics
    doc_topics = [lda_model.get_document_topics(item, minimum_probability=0.0000001) for item in corpus]
    
    # Initialize topic columns in EC_data
    for topic_num in range(10):
        data[f'topic_{topic_num}'] = 0.0
    
    # Fill topic share in EC_data
    for i, doc_distribution in enumerate(doc_topics):
        for topic_num, prob in doc_distribution:
            data.at[i, f'topic_{topic_num}'] = prob
    
    # Calculate sum of topic shares and check if it's close to 1
    data['topic_sum'] = data[[f'topic_{i}' for i in range(10)]].sum(axis=1)
    data['sum_is_1'] = np.isclose(data['topic_sum'], 1.0)
    
    # Calculate words per topic
    data['length_in_words'] = data['text_preproc'].apply(lambda x: len(x.split()))
    for i in range(10):
        data[f'words_topic_{i}'] = data[f'topic_{i}'] * data['length_in_words']
    
    # Correctly convert the 'Date' column to 'year_month' format
    data['year_month'] = pd.to_datetime(data['Date']).dt.strftime('%Y-%m')
    aggregation_data = data[['year_month'] + [f'words_topic_{i}' for i in range(10)]]
    grouped_data = aggregation_data.groupby(['year_month']).sum().reset_index()
    
    # Adjust sums by alpha_prior and calculate topic shares
    alpha_prior = lda_model.alpha
    total_alpha_prior = sum(alpha_prior)
    for i in range(10):
        grouped_data[f'topic_share_{i}'] = (grouped_data[f'words_topic_{i}'] + alpha_prior[i]) / (grouped_data[[f'words_topic_{j}' for j in range(10)]].sum(axis=1) + total_alpha_prior)
    
    # Select final columns for the result DataFrame
    final_columns = ['year_month'] + [f'topic_share_{i}' for i in range(10)]
    result_df = grouped_data[final_columns]
    
    return result_df

EC_topic_shares = aggregate_topic_shares(EC_data, lda_model_ECB, corpus_ECB)
WH_topic_shares = aggregate_topic_shares(WH_data, lda_model_WH, corpus_WH)

# %%
EC_topic_shares.head(5)
# Out:
#   year_month  topic_share_0  topic_share_1  topic_share_2  topic_share_3  \
# 0    2021-01       0.356892       0.003795       0.096965       0.161241
# 1    2021-02       0.329354       0.006288       0.139205       0.021685
# 2    2021-03       0.238231       0.039556       0.185921       0.145070
# 3    2021-04       0.238909       0.047434       0.237715       0.116636
# 4    2021-05       0.317908       0.070887       0.180929       0.068403
#
#    topic_share_4  topic_share_5  topic_share_6  topic_share_7  topic_share_8  \
# 0       0.015841       0.135680       0.001440       0.103094       0.101917
# 1       0.022975       0.358524       0.032891       0.041025       0.034469
# 2       0.039599       0.159665       0.025212       0.111128       0.044852
# 3       0.072486       0.059975       0.033427       0.168863       0.023780
# 4       0.057165       0.146929       0.013313       0.067915       0.024737
#
#    topic_share_9
# 0       0.023136
# 1       0.013585
# 2       0.010765
# 3       0.000774
# 4       0.051813

# %%
WH_topic_shares.head(5)

# %%
# Plotting
plt.figure(figsize=(12, 6))

# Plot each topic share over time within the filtered range
for i in range(10):  # Assuming topic_share columns are named from 'topic_share_0' to 'topic_share_14'
    plt.plot(EC_topic_shares['year_month'], EC_topic_shares[f'topic_share_{i}'], label=f'Topic {i}')

# Rotate the x-axis tick labels for better readability
plt.xticks(rotation=45)

# Adding labels and title
plt.xlabel('Year-Month')
plt.ylabel('Topic Share')
plt.title('Yearly Topic Share for Topics 0 to 14')

plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
def plot_topic_shares_over_time(result_df, topic1, topic2):
    plt.figure(figsize=(12, 6))  # Increase figure size for better readability
    
    # Plot for the first selected topic with improved line style and marker size
    plt.plot(result_df['year_month'], result_df[f'topic_share_{topic1}'], label=f'Topic {topic1}',
             marker='o', linestyle='-', color='blue', linewidth=2, markersize=8)
    
    # Plot for the second selected topic with different line style and marker size
    plt.plot(result_df['year_month'], result_df[f'topic_share_{topic2}'], label=f'Topic {topic2}',
             marker='x', linestyle='--', color='red', linewidth=2, markersize=8)
    
    # Rotate the x-axis tick labels for better readability
    plt.xticks(rotation=45)
    
    # Adding labels, title, and gridlines
    plt.xlabel('Year-Month')
    plt.ylabel('Topic Share')
    plt.title(f'Yearly Topic Share for Topics {topic1} and {topic2}')
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)  # Add


plot_topic_shares_over_time(EC_topic_shares, 0, 1)
